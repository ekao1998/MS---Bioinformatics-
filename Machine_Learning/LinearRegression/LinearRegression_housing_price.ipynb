# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Machine learning/lab03
# Out:
# /content/drive/MyDrive/Colab Notebooks/Machine learning/lab03

# %% [markdown]
# **Lab a**

# %% [markdown]
# **Q1**

# %%
import pandas as pd

# %%
housing = pd.read_csv("housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %% [markdown]
# **Q2**

# %%
housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# **Q3**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# **Q4**

# %%
# set time marker
import datetime
now = datetime.datetime.now()
print ("Running the lab03 step5 at date and time: ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Running the lab03 step5 at date and time:
# 2022-10-08 20:28:18

# %%
# to make this notebook's output identical at every run
# .seed(), is to save the state of a random function, so that it can generate the same random numbers on multiple executions of the code.
import numpy as np
np.random.seed(10)

# %%
# For illustration only. Sklearn has train_test_split()
def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
# run the function to get the train & test set
train_set, test_set = split_train_test(housing, 0.2)

# %%
train_set.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346    -116.52     33.82                21.0      10227.0          2315.0
# 19326    -122.94     38.50                46.0       2280.0           492.0
# 16824    -122.49     37.63                31.0       3109.0           621.0
# 6869     -118.11     34.06                16.0       2416.0           565.0
# 16677    -120.66     35.13                41.0       2666.0           751.0
# ...          ...       ...                 ...          ...             ...
# 9372     -122.53     37.93                37.0       1722.0           352.0
# 7291     -118.22     33.98                18.0       1781.0           765.0
# 17728    -121.79     37.32                 6.0       2850.0           561.0
# 7293     -118.23     33.98                35.0       1366.0           496.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
#
#        population  households  median_income  median_house_value
# 12346      3623.0      1734.0         2.5212            145200.0
# 19326       807.0       366.0         2.6316            117000.0
# 16824      1472.0       618.0         5.1550            263900.0
# 6869       1750.0       514.0         2.8229            163700.0
# 16677       940.0       507.0         1.9653            236100.0
# ...           ...         ...            ...                 ...
# 9372        648.0       337.0         4.1250            310300.0
# 7291       1913.0       702.0         1.2059            255000.0
# 17728      2160.0       581.0         5.5336            241900.0
# 7293       2160.0       497.0         2.2059            150000.0
# 17673      1674.0       681.0         2.6763            191100.0
#
# [16512 rows x 9 columns]>

# %%
test_set.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20303    -119.18     34.16                12.0        460.0           101.0
# 16966    -122.31     37.55                27.0       3931.0           933.0
# 10623    -117.77     33.67                12.0       4329.0          1068.0
# 6146     -117.95     34.11                29.0       1986.0           448.0
# 2208     -119.87     36.81                 6.0       1891.0           341.0
# ...          ...       ...                 ...          ...             ...
# 3263     -122.88     39.14                20.0       1125.0           231.0
# 11694    -117.98     33.89                18.0       2939.0           437.0
# 1729     -122.34     37.98                33.0       2014.0           410.0
# 5087     -118.28     33.98                45.0       1720.0           416.0
# 6581     -118.20     34.21                40.0       1477.0           228.0
#
#        population  households  median_income  median_house_value
# 20303       405.0       103.0         5.2783            167400.0
# 16966      1877.0       851.0         3.9722            354100.0
# 10623      1913.0       978.0         4.5094            160200.0
# 6146       2013.0       432.0         3.1034            140800.0
# 2208        969.0       330.0         4.6726            107800.0
# ...           ...         ...            ...                 ...
# 3263        521.0       196.0         2.2188            106300.0
# 11694      1278.0       435.0         7.1425            393700.0
# 1729       1354.0       427.0         3.9773            131300.0
# 5087       1382.0       365.0         0.9337             92300.0
# 6581        609.0       224.0         7.8375            500001.0
#
# [4128 rows x 9 columns]>

# %%
train_set.shape[0] + test_set.shape[0] == 20640
# Out:
# True

# %% [markdown]
# **Q5**

# %%
from sklearn.model_selection import train_test_split
train_set2, test_set2 = train_test_split(housing, test_size=0.2, random_state=10)

# %%
train_set2.info
# Out:
# <bound method DataFrame.info of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346    -116.52     33.82                21.0      10227.0          2315.0
# 19326    -122.94     38.50                46.0       2280.0           492.0
# 16824    -122.49     37.63                31.0       3109.0           621.0
# 6869     -118.11     34.06                16.0       2416.0           565.0
# 16677    -120.66     35.13                41.0       2666.0           751.0
# ...          ...       ...                 ...          ...             ...
# 9372     -122.53     37.93                37.0       1722.0           352.0
# 7291     -118.22     33.98                18.0       1781.0           765.0
# 17728    -121.79     37.32                 6.0       2850.0           561.0
# 7293     -118.23     33.98                35.0       1366.0           496.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
#
#        population  households  median_income  median_house_value
# 12346      3623.0      1734.0         2.5212            145200.0
# 19326       807.0       366.0         2.6316            117000.0
# 16824      1472.0       618.0         5.1550            263900.0
# 6869       1750.0       514.0         2.8229            163700.0
# 16677       940.0       507.0         1.9653            236100.0
# ...           ...         ...            ...                 ...
# 9372        648.0       337.0         4.1250            310300.0
# 7291       1913.0       702.0         1.2059            255000.0
# 17728      2160.0       581.0         5.5336            241900.0
# 7293       2160.0       497.0         2.2059            150000.0
# 17673      1674.0       681.0         2.6763            191100.0
#
# [16512 rows x 9 columns]>

# %%
train_set == train_set2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346       True      True                True         True            True
# 19326       True      True                True         True            True
# 16824       True      True                True         True            True
# 6869        True      True                True         True            True
# 16677       True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 9372        True      True                True         True            True
# 7291        True      True                True         True            True
# 17728       True      True                True         True            True
# 7293        True      True                True         True            True
# 17673       True      True                True         True            True
#
#        population  households  median_income  median_house_value
# 12346        True        True           True                True
# 19326        True        True           True                True
# 16824        True        True           True                True
# 6869         True        True           True                True
# 16677        True        True           True                True
# ...           ...         ...            ...                 ...
# 9372         True        True           True                True
# 7291         True        True           True                True
# 17728        True        True           True                True
# 7293         True        True           True                True
# 17673        True        True           True                True
#
# [16512 rows x 9 columns]

# %%
test_set == test_set2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20303       True      True                True         True            True
# 16966       True      True                True         True            True
# 10623       True      True                True         True            True
# 6146        True      True                True         True            True
# 2208        True      True                True         True            True
# ...          ...       ...                 ...          ...             ...
# 3263        True      True                True         True            True
# 11694       True      True                True         True            True
# 1729        True      True                True         True            True
# 5087        True      True                True         True            True
# 6581        True      True                True         True            True
#
#        population  households  median_income  median_house_value
# 20303        True        True           True                True
# 16966        True        True           True                True
# 10623        True        True           True                True
# 6146         True        True           True                True
# 2208         True        True           True                True
# ...           ...         ...            ...                 ...
# 3263         True        True           True                True
# 11694        True        True           True                True
# 1729         True        True           True                True
# 5087         True        True           True                True
# 6581         True        True           True                True
#
# [4128 rows x 9 columns]

# %% [markdown]
# **Q6**

# %%
# s us for marker size, c is for color values
train_set.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, 
    s=train_set["population"]/100, label="population", figsize=(10,7),
    c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
    sharex=False)
plt.legend()
plt.show()

# %% [markdown]
# **Lab b**

# %% [markdown]
# **Q7**

# %%
train_set.count()
# Out:
# longitude             16512
# latitude              16512
# housing_median_age    16512
# total_rooms           16512
# total_bedrooms        16346
# population            16512
# households            16512
# median_income         16512
# median_house_value    16512
# dtype: int64

# %%
train_set[train_set.isna().any(axis=1)]
# .isna(), Detect missing values.
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6814     -118.07     34.10                32.0       4275.0             NaN
# 4738     -118.38     34.05                49.0        702.0             NaN
# 290      -122.16     37.77                47.0       1256.0             NaN
# 19833    -119.38     36.53                38.0       1281.0             NaN
# 4852     -118.31     34.03                47.0       1315.0             NaN
# ...          ...       ...                 ...          ...             ...
# 11512    -118.10     33.74                32.0       2035.0             NaN
# 13656    -117.30     34.05                 6.0       2155.0             NaN
# 13015    -121.19     38.71                11.0       4415.0             NaN
# 10236    -117.92     33.87                33.0       1597.0             NaN
# 14521    -117.14     32.90                16.0       3217.0             NaN
#
#        population  households  median_income  median_house_value
# 6814       2812.0      1012.0         3.3512            214100.0
# 4738        458.0       187.0         4.8958            333600.0
# 290         570.0       218.0         4.3750            161900.0
# 19833      1423.0       293.0         1.9602             51400.0
# 4852        785.0       245.0         1.2300            138400.0
# ...           ...         ...            ...                 ...
# 11512       934.0       512.0         4.2287            500001.0
# 13656      1039.0       391.0         1.6675             95800.0
# 13015      1520.0       627.0         3.2321            390800.0
# 10236      1888.0       423.0         3.0550            157800.0
# 14521      2054.0       687.0         4.2234            162100.0
#
# [166 rows x 9 columns]

# %%
train_set_clean = train_set.dropna(subset=["total_bedrooms"])
train_set_clean
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12346    -116.52     33.82                21.0      10227.0          2315.0
# 19326    -122.94     38.50                46.0       2280.0           492.0
# 16824    -122.49     37.63                31.0       3109.0           621.0
# 6869     -118.11     34.06                16.0       2416.0           565.0
# 16677    -120.66     35.13                41.0       2666.0           751.0
# ...          ...       ...                 ...          ...             ...
# 9372     -122.53     37.93                37.0       1722.0           352.0
# 7291     -118.22     33.98                18.0       1781.0           765.0
# 17728    -121.79     37.32                 6.0       2850.0           561.0
# 7293     -118.23     33.98                35.0       1366.0           496.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
#
#        population  households  median_income  median_house_value
# 12346      3623.0      1734.0         2.5212            145200.0
# 19326       807.0       366.0         2.6316            117000.0
# 16824      1472.0       618.0         5.1550            263900.0
# 6869       1750.0       514.0         2.8229            163700.0
# 16677       940.0       507.0         1.9653            236100.0
# ...           ...         ...            ...                 ...
# 9372        648.0       337.0         4.1250            310300.0
# 7291       1913.0       702.0         1.2059            255000.0
# 17728      2160.0       581.0         5.5336            241900.0
# 7293       2160.0       497.0         2.2059            150000.0
# 17673      1674.0       681.0         2.6763            191100.0
#
# [16346 rows x 9 columns]

# %%
train_set_clean[train_set_clean.isna().any(axis=1)]
# can see from the result no missing value
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value]
# Index: []

# %%
train_set_clean.count()
# Out:
# longitude             16346
# latitude              16346
# housing_median_age    16346
# total_rooms           16346
# total_bedrooms        16346
# population            16346
# households            16346
# median_income         16346
# median_house_value    16346
# dtype: int64

# %% [markdown]
# **Q8**

# %%
# set time marker
import datetime
now = datetime.datetime.now()
print ("Running the lab03 step8 at date and time: ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Running the lab03 step8 at date and time:
# 2022-10-08 20:28:20

# %%
train_labels = train_set_clean["median_house_value"].copy() # get labels for output label Y
train_features = train_set_clean.drop("median_house_value", axis=1) # drop labels to get features X for training set

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16346 entries, 12346 to 17673
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           16346 non-null  float64
#  1   latitude            16346 non-null  float64
#  2   housing_median_age  16346 non-null  float64
#  3   total_rooms         16346 non-null  float64
#  4   total_bedrooms      16346 non-null  float64
#  5   population          16346 non-null  float64
#  6   households          16346 non-null  float64
#  7   median_income       16346 non-null  float64
# dtypes: float64(8)
# memory usage: 1.1 MB

# %%
train_features.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16346.000000  16346.000000        16346.000000  16346.000000
# mean    -119.576731     35.639888           28.606265   2630.196745
# std        2.006389      2.139648           12.632219   2158.731496
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.500000     34.260000           29.000000   2125.500000
# 75%     -118.010000     37.720000           37.000000   3137.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    16346.000000  16346.000000  16346.000000   16346.000000
# mean       537.625413   1425.149456    498.992659       3.864135
# std        418.511077   1136.460782    378.999712       1.892231
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    785.000000    279.000000       2.559275
# 50%        435.000000   1165.500000    409.000000       3.533800
# 75%        647.000000   1728.000000    605.000000       4.739900
# max       6445.000000  35682.000000   6082.000000      15.000100

# %%
train_labels
# Out:
# 12346    145200.0
# 19326    117000.0
# 16824    263900.0
# 6869     163700.0
# 16677    236100.0
#            ...
# 9372     310300.0
# 7291     255000.0
# 17728    241900.0
# 7293     150000.0
# 17673    191100.0
# Name: median_house_value, Length: 16346, dtype: float64

# %%
train_labels.hist()
plt.ylabel("count", fontsize = 20)
plt.xlabel("value", fontsize = 20)
plt.title("train_labels", fontsize = 20)
plt.show()

# %% [markdown]
# **Q9**

# %%
train_features.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f013a41cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f014708ee50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0147071a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0146fde510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0146f8f550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0147461e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f01471449d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0147479c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01474762d0>]],
#       dtype=object)

# %%
train_features.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16346.000000  16346.000000        16346.000000  16346.000000
# mean    -119.576731     35.639888           28.606265   2630.196745
# std        2.006389      2.139648           12.632219   2158.731496
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.500000     34.260000           29.000000   2125.500000
# 75%     -118.010000     37.720000           37.000000   3137.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    16346.000000  16346.000000  16346.000000   16346.000000
# mean       537.625413   1425.149456    498.992659       3.864135
# std        418.511077   1136.460782    378.999712       1.892231
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    785.000000    279.000000       2.559275
# 50%        435.000000   1165.500000    409.000000       3.533800
# 75%        647.000000   1728.000000    605.000000       4.739900
# max       6445.000000  35682.000000   6082.000000      15.000100

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() ## define the transformer
scaler.fit(train_features) ## call .fit() method to calculate the min and max value for each column in dataset
# Out:
# MinMaxScaler()

# %%
print("Min of each column: ",scaler.data_min_)
print("Max of each column: ",scaler.data_max_)
# Out:
# Min of each column:  [-124.35     32.54      1.        2.        1.        3.        1.
#     0.4999]
# Max of each column:  [-1.14310e+02  4.19500e+01  5.20000e+01  3.93200e+04  6.44500e+03
#   3.56820e+04  6.08200e+03  1.50001e+01]

# %%
train_features.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  16346.000000  16346.000000        16346.000000  16346.000000
# mean    -119.576731     35.639888           28.606265   2630.196745
# std        2.006389      2.139648           12.632219   2158.731496
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1451.000000
# 50%     -118.500000     34.260000           29.000000   2125.500000
# 75%     -118.010000     37.720000           37.000000   3137.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    16346.000000  16346.000000  16346.000000   16346.000000
# mean       537.625413   1425.149456    498.992659       3.864135
# std        418.511077   1136.460782    378.999712       1.892231
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    785.000000    279.000000       2.559275
# 50%        435.000000   1165.500000    409.000000       3.533800
# 75%        647.000000   1728.000000    605.000000       4.739900
# max       6445.000000  35682.000000   6082.000000      15.000100

# %%
train_features_normalized = scaler.transform(train_features)
train_features_normalized
# Out:
# array([[0.77988048, 0.1360255 , 0.39215686, ..., 0.10146024, 0.28498602,
#         0.13939808],
#        [0.14043825, 0.63336876, 0.88235294, ..., 0.02253426, 0.06002302,
#         0.14701177],
#        [0.18525896, 0.54091392, 0.58823529, ..., 0.04117268, 0.10146358,
#         0.32103695],
#        ...,
#        [0.25498008, 0.50797024, 0.09803922, ..., 0.06045573, 0.09537905,
#         0.34714694],
#        [0.60956175, 0.15302869, 0.66666667, ..., 0.06045573, 0.08156553,
#         0.11765355],
#        [0.24601594, 0.50584485, 0.29411765, ..., 0.04683427, 0.11182371,
#         0.15009448]])

# %%
pd.DataFrame(train_features_normalized).hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# **Lab c**

# %% [markdown]
# **Q10a**

# %%
from sklearn.linear_model import LinearRegression ## import the LinearRegression Function
lin_reg = LinearRegression() ## Initialize the class
lin_reg.fit(train_features_normalized, train_labels) # feed the training data X, and label Y for supervised learning
# Out:
# LinearRegression()

# %% [markdown]
# **Q10b**

# %%
# set time marker
import datetime
now = datetime.datetime.now()
print ("Running the lab03 step10b at date and time: ")
print (now.strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# Running the lab03 step10b at date and time:
# 2022-10-08 20:28:28

# %%
training_predictions = lin_reg.predict(train_features_normalized)
training_predictions
# Out:
# array([203632.55175488, 214275.00175551, 310476.31666651, ...,
#        249100.07116218, 139778.76969173, 194768.21087041])

# %%
print(len(training_predictions))
print(train_labels.count)
# Out:
# 16346
# <bound method Series.count of 12346    145200.0
# 19326    117000.0
# 16824    263900.0
# 6869     163700.0
# 16677    236100.0
#            ...
# 9372     310300.0
# 7291     255000.0
# 17728    241900.0
# 7293     150000.0
# 17673    191100.0
# Name: median_house_value, Length: 16346, dtype: float64>

# %%
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.hist(training_predictions)
plt.subplot(1,2,2)
plt.hist(train_labels)
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, train_labels)## plot scatter plot 
import matplotlib.pyplot as plt
plt.scatter(training_predictions, train_labels )
plt.xlabel('training_predictions', fontsize=15,color="red")
plt.ylabel('train_label', fontsize=15,color="green")
plt.title('Scatter plot for training_predictions and train_label', fontsize=15)
plt.xlim(0,np.max(training_predictions)) # remove the predictions that have negative prices
plt.show()

# %%
import numpy as np
np.corrcoef(training_predictions, train_labels)
# Out:
# array([[1.       , 0.7982524],
#        [0.7982524, 1.       ]])

# %% [markdown]
# **Q10c**

# %%
import pandas as pd 
prediction_summary = pd.DataFrame({'predicted_label':training_predictions, 'actual_label':train_labels})
prediction_summary
# Out:
#        predicted_label  actual_label
# 12346    203632.551755      145200.0
# 19326    214275.001756      117000.0
# 16824    310476.316667      263900.0
# 6869     148350.680663      163700.0
# 16677    255784.876966      236100.0
# ...                ...           ...
# 9372     263458.312355      310300.0
# 7291     123985.171504      255000.0
# 17728    249100.071162      241900.0
# 7293     139778.769692      150000.0
# 17673    194768.210870      191100.0
#
# [16346 rows x 2 columns]

# %%
prediction_summary['error'] = prediction_summary['actual_label'] - prediction_summary['predicted_label']
prediction_summary
# Out:
#        predicted_label  actual_label          error
# 12346    203632.551755      145200.0  -58432.551755
# 19326    214275.001756      117000.0  -97275.001756
# 16824    310476.316667      263900.0  -46576.316667
# 6869     148350.680663      163700.0   15349.319337
# 16677    255784.876966      236100.0  -19684.876966
# ...                ...           ...            ...
# 9372     263458.312355      310300.0   46841.687645
# 7291     123985.171504      255000.0  131014.828496
# 17728    249100.071162      241900.0   -7200.071162
# 7293     139778.769692      150000.0   10221.230308
# 17673    194768.210870      191100.0   -3668.210870
#
# [16346 rows x 3 columns]

# %%
from sklearn.metrics import mean_squared_error
lin_mse = mean_squared_error(train_labels, training_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 69311.00758655458

# %% [markdown]
# **Q10d**

# %%
## Step 1: training the data using decision tree algorithm
from sklearn.tree import DecisionTreeRegressor ## import the DecisionTree Function
tree_reg = DecisionTreeRegressor(random_state=42) ## Initialize the class
tree_reg.fit(train_features_normalized, train_labels) # feed the training data X, and label Y for supervised learning
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
### Step 2: make a prediction using tree model
training_predictions_trees = tree_reg.predict(train_features_normalized)
training_predictions_trees
# Out:
# array([145200., 117000., 263900., ..., 241900., 150000., 191100.])

# %%
## Step 3: visualize the scatter plot between predictions and actual labels
import matplotlib.pyplot as plt
plt.scatter(training_predictions_trees, train_labels )
plt.xlabel('training_predictions_trees', fontsize=15,color="red")
plt.ylabel('train_label', fontsize=15,color="green")
plt.title('Scatter plot for training_predictions_trees and train_label', fontsize=15)
plt.xlim(0,np.max(training_predictions_trees)) # remove the predictions that have negative prices
plt.show()

# %%
from sklearn.metrics import mean_squared_error
tree_mse = mean_squared_error(train_labels, training_predictions_trees)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 0.0

# %% [markdown]
# **Q12**

# %%
## 1. clean the missing values in test set
test_set_clean = test_set.dropna(subset=["total_bedrooms"])
test_set_clean

## 2. derive test features and test labels. In this case, test labels are only used for evaluation
test_labels = test_set_clean["median_house_value"].copy() # get labels for output label Y
test_features = test_set_clean.drop("median_house_value", axis=1) # drop labels to get features X for training set


## 4. scale the numeric features in test set. 
## important note: do not apply fit function on the test set, using same scalar from training set
test_features_normalized = scaler.transform(test_features)
test_features_normalized
# Out:
# array([[0.51494024, 0.17215728, 0.21568627, ..., 0.01126713, 0.01677356,
#         0.32954028],
#        [0.20318725, 0.53241233, 0.50980392, ..., 0.05252389, 0.13977964,
#         0.23946566],
#        [0.65537849, 0.12008502, 0.21568627, ..., 0.05353289, 0.16066436,
#         0.27651343],
#        ...,
#        [0.2001992 , 0.5781084 , 0.62745098, ..., 0.03786541, 0.07005427,
#         0.23981738],
#        [0.60458167, 0.15302869, 0.8627451 , ..., 0.03865019, 0.05985858,
#         0.02991683],
#        [0.6125498 , 0.17747078, 0.76470588, ..., 0.01698478, 0.0366716 ,
#         0.5060344 ]])

# %%
### Step 5: make a prediction using tree model
test_predictions_trees = tree_reg.predict(test_features_normalized)
test_predictions_trees
# Out:
# array([218000., 290000., 273600., ..., 162800.,  91700., 281900.])

# %%
from sklearn.metrics import mean_squared_error
test_tree_mse = mean_squared_error(test_labels, test_predictions_trees)
test_tree_rmse = np.sqrt(test_tree_mse)
test_tree_rmse
# Out:
# 65700.6428440179

# %% [markdown]
# **Gradio**

# %% [markdown]
# **Q1**

# %%
# Step 1: install Gradio
# !pip install --quiet gradio
# Out:
#      |████████████████████████████████| 5.3 MB 2.1 MB/s
#      |████████████████████████████████| 212 kB 26.2 MB/s
#      |████████████████████████████████| 84 kB 1.7 MB/s
#      |████████████████████████████████| 55 kB 1.7 MB/s
#      |████████████████████████████████| 84 kB 3.0 MB/s
#      |████████████████████████████████| 57 kB 4.1 MB/s
#      |████████████████████████████████| 2.3 MB 33.2 MB/s
#      |████████████████████████████████| 270 kB 49.3 MB/s
#      |████████████████████████████████| 112 kB 69.6 MB/s
#      |████████████████████████████████| 54 kB 3.4 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
#      |████████████████████████████████| 80 kB 8.7 MB/s
#      |████████████████████████████████| 68 kB 6.3 MB/s
#      |████████████████████████████████| 46 kB 3.6 MB/s
#      |████████████████████████████████| 4.0 MB 47.3 MB/s
#      |████████████████████████████████| 594 kB 60.4 MB/s
#      |████████████████████████████████| 856 kB 58.2 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %% [markdown]
# **Q2**

# %%
# Step 2: import library
import gradio as gr
print(gr.__version__)
# Out:
# 3.4.1

# %% [markdown]
# **Q3**

# %%
# Step 3.1: Define a simple "Hello World" function
# requirement: input is text, output is text
def greet(name):
      return "Hello " + name + "!!"

# Step 3.2: Define the input component (text style) and output component (text style) to create a simple GUI
import gradio as gr
input_module = gr.inputs.Textbox(label = "Input Text")
output_module = gr.outputs.Textbox(label = "Output Text")

# Step 3.3: Put all three component together into the gradio's interface function 
gr.Interface(fn=greet, inputs=input_module, outputs=output_module).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://14526.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://14526.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f012f657650>,
#  'http://127.0.0.1:7860/',
#  'https://14526.gradio.app')

# %%
def square(x):
  return int(x)*int(x)

input = gr.inputs.Textbox(label = "Input a number")
output = gr.outputs.Textbox(label = "Square result")
gr.Interface(fn=square, inputs=input, outputs=output).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://27083.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://27083.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f012f2bd990>,
#  'http://127.0.0.1:7861/',
#  'https://27083.gradio.app')

# %% [markdown]
# **Q4**

# %%
# Step 3.1: Define a simple "Hello World" function
# requirement: input is text, output is text
def greet(name):
      return "Hello " + name + "!!"

# Step 3.2: Define the input component (text style) and output component (text style) to create a simple GUI
import gradio as gr
input_module = gr.inputs.Textbox(label = "Input Text")
output_module = gr.outputs.Textbox(label = "Output Text")


# Step 3.4: Define the examples, the example type must match the type of input_module
examples = [["June 1st"], ["Week 2"]]

# Step 3.3: Put all three component together into the gradio's interface function 
gr.Interface(fn=greet, inputs=input_module, outputs=output_module,examples = examples).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://17276.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://17276.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f012b184b50>,
#  'http://127.0.0.1:7862/',
#  'https://17276.gradio.app')

# %%
def square(x):
  f = float(x)*float(x)
  return "%.2f"%f

input = gr.inputs.Textbox(label = "Input a number")
output = gr.outputs.Textbox(label = "Square result")
examples = [[4],[5],[1.1]]
gr.Interface(fn=square, inputs=input, outputs=output, examples = examples).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://29785.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://29785.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f012f6ab610>,
#  'http://127.0.0.1:7863/',
#  'https://29785.gradio.app')

# %% [markdown]
# **Q5**

# %%
# Step 5.1: Define a simple "image-to-text" function
# requirement: input is text, output is text

def caption(image):
    return "Image is processed!!"

# Step 5.2: Define the input component (image style) and output component (text style) to create a simple GUI
import gradio as gr
input_module = gr.inputs.Image(label = "Input Image")
output_module = gr.outputs.Textbox(label = "Output Text")

# Step 5.3: Put all three component together into the gradio's interface function 
gr.Interface(fn=caption, inputs=input_module, outputs=output_module).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://27735.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://27735.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f01288ad650>,
#  'http://127.0.0.1:7864/',
#  'https://27735.gradio.app')

# %% [markdown]
# **Q6**

# %%
# Step 6.1: Define different input components
import gradio as gr

# a. define text data type
input_module1 = gr.inputs.Textbox(label = "Input Text")

# b. define image data type
input_module2 = gr.inputs.Image(label = "Input Image")

# c. define Number data type
input_module3 = gr.inputs.Number(label = "Input Number")

# d. define Slider data type
input_module4 = gr.inputs.Slider(1, 100, step=5, label = "Input Slider")

# e. define Checkbox data type
input_module5 = gr.inputs.Checkbox(label = "Does it work?")

# f. define Radio data type
input_module6 = gr.inputs.Radio(choices=["park", "zoo", "road"], label = "Input Radio")

# g. define Dropdown data type
input_module7 = gr.inputs.Dropdown(choices=["park", "zoo", "road"], label = "Input Dropdown")

# Step 6.2: Define different output components
# a. define text data type
output_module1 = gr.outputs.Textbox(label = "Output Text")

# b. define image data type
output_module2 = gr.outputs.Image(label = "Output Image")

# you can define more output components

# Step 6.3: Define a new function that accommodates the input modules.
def multi_inputs(input1, input2, input3, input4, input5, input6, input7 ):
    import numpy as np
    ## processing inputs

    ## return outputs
    output1 = "Processing inputs and return outputs" # text output example
    output2 = np.random.rand(6,6) # image-like array output example
    return output1,output2

# Step 6.4: Put all three component together into the gradio's interface function 
gr.Interface(fn=multi_inputs, 
             inputs=[input_module1, input_module2, input_module3,
                     input_module4, input_module5, input_module6,
                     input_module7], 
             outputs=[output_module1, output_module2]
            ).launch()
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:27: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `numeric` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:59: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:89: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:121: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:183: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:217: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:43: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://13377.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://13377.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x7f011d9377d0>,
#  'http://127.0.0.1:7866/',
#  'https://13377.gradio.app')

# %% [markdown]
# **Q7**

# %%
import pandas as pd
input_module1 = gr.inputs.Slider(-124, -114.35, step=0.5, label = "Longitude")
input_module2 = gr.inputs.Slider(32, 42, step=0.5, label = "Latitude")
input_module3 = gr.inputs.Slider(1, 52, step=1, label = "Housing_median_age (Year)")
input_module4 = gr.inputs.Slider(1, 39996, step=1, label = "Total_rooms")
input_module5 = gr.inputs.Slider(1, 100, step=5, label = "Total_bedrooms")
input_module6 = gr.inputs.Slider(3, 35678, step=1, label = "Population")
input_module7 = gr.inputs.Slider(1, 6081, step=1, label = "Households")
input_module8 = gr.inputs.Slider(0, 15, step=1, label = "Median_income")

output_module1 = gr.outputs.Textbox(label = "Predicted Housing Prices")
output_module2 = gr.Plot(label = "Output Image")

def predictions_trees(input1, input2, input3, input4, input5, input6, input7, input8 ):
    import numpy as np
    import matplotlib.pyplot as plt
    ## processing inputs
    x = {
    'longitude': [input1],
     'latitude': [input2],
     'housing_median_age': [input3],
     'total_rooms': [input4],
     'total_bedrooms': [input5],
     'population':	[input6],
     'households':	[input7],
     'median_income':[input8]
    }
    input = pd.DataFrame(x) # transform require this format
    features_normalized = scaler.transform(input) 
    predictions_trees = tree_reg.predict(features_normalized)
# use tree reg will get int result, use lin reg will get float result as demo shows
    output1 = predictions_trees
  
    output2 = plt.figure()
    plt.scatter(x=train_set["longitude"], y=train_set["latitude"], alpha=0.4, 
    s=train_set["population"]/100, label="population"
    )
    plt.annotate("Here!",(input1,input2))
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    # train_set.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4, 
    # s=train_set["population"]/100, label="population", figsize=(10,7),
    # c="median_house_value", cmap=plt.get_cmap("jet"), colorbar=True,
    # sharex=False)
    
    plt.plot(input1,input2,"ro", markersize = 15)
    plt.legend()
    plt.show()
    return output1[0], output2

examples = [[-118.3,34.06,23,2512,1203,3720,1118,1.7896],
            [-120.67,38.19,17,2967,611,1387,564,2.0417],
            [-117.23,32.73,35,2914,683,1562,638,2.5259],
            [-117.93,33.79,34,3592,616,2138,605,5.2129],
            [-121.96,37.54,14,5106,1207,2738,1108,3.9909]
           ]
# Step 6.4: Put all three component together into the gradio's interface function 
gr.Interface(fn=predictions_trees, 
             inputs=[input_module1, input_module2, input_module3,
                     input_module4, input_module5, input_module6,
                     input_module7, input_module8], 
             outputs=[output_module1, output_module2],
             title = 'CSCI4750/5750 Demo 3: Web Application for Housing Price Prediction',
             description="Enter all features and predicted the housing price.",
             examples = examples
            ).launch(debug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/inputs.py:89: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   "Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.7/dist-packages/gradio/outputs.py:22: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   "Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components",
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://22341.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://22341.gradio.app" width="900" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Keyboard interruption in main thread... closing server.
# (<gradio.routes.App at 0x7f01226d1810>,
#  'http://127.0.0.1:7866/',
#  'https://22341.gradio.app')

# %% [markdown]
# **Function testing**

# %%
def predictions_trees(input1, input2, input3, input4, input5, input6, input7, input8 ):
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    ## processing inputs
    x = {
    'longitude': [input1],
     'latitude': [input2],
     'housing_median_age': [input3],
     'total_rooms': [input4],
     'total_bedrooms': [input5],
     'population':	[input6],
     'households':	[input7],
     'median_income':[input8]
    }
    input = pd.DataFrame(x) # transform require this format
    features_normalized = scaler.transform(input) 
    predictions_trees = tree_reg.predict(features_normalized)
    out2 = plt.figure()
    plt.scatter(x=train_set["longitude"], y=train_set["latitude"], alpha=0.4, 
    s=train_set["population"]/100, label="population"
    )
   

    plt.plot(input1,input2,"ro", markersize = 15)
    plt.legend()
    plt.show()
    out1 = predictions_trees
    return out1, out2
print(predictions_trees(-118.3,34.06,23,2512,1203,3720,1118,1.7896))
# Out:
# (array([322200.]), <Figure size 432x288 with 1 Axes>)

# %%
import pandas as pd
x = {
    'longitude': [-118.3],
     'latitude': [34.06],
     'housing_median_age': [23],
     'total_rooms': [2512],
     'total_bedrooms': [1203],
     'population':	[3720],
     'households':	[1118],
     'median_income':[1.7896]
}
input = pd.DataFrame(x)

# input = np.array([[-118.3,34.06,23,2512,1203,3720,1118,1.7896]])
test_features_normalized = scaler.transform(input)
test_features_normalized
# Out:
# array([[0.60258964, 0.16153029, 0.43137255, 0.06383845, 0.18653011,
#         0.10417893, 0.18368689, 0.0889436 ]])
