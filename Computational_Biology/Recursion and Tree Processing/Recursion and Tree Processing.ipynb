# %% [markdown]
# **determining the total number of nodes in a tree**

# %%
def countNodes(tree):
    """Return the total number of nodes in the given tree."""
    root,first,second = tree    # unpack the tuple
    if first == second == ():
        return 1     # this tree is itself a leaf
    else:
        return 1 + countNodes(first) + countNodes(second)

# %% [markdown]
# **determining the maximum height of a tree**

# %%
def height(tree):
    """Return the length of the longest branch of the tree."""
    root,first,second = tree    # unpack the tuple

    if first == second == ():
        return 0     # a leaf has height 0

    else:
        return 1 + max(height(first), height(second))

# %% [markdown]
# **producing a list of labels for all of the leaves of a tree**

# %%
def leafList(tree):
    """Return list of labels for the leaves of the tree."""
    root,first,second = tree    # unpack the tuple
    if first == second == ():
        return [ root ]       # tree with one node
    else:
        return leafList(first) + leafList(second)

# %% [markdown]
# **Q1**

# %%
tree1 = ('A',
     ('B',
          ('C',(),()),
          ('D',(),())
     ),
     ('E',(),())
)

same_tree = ('A', ('B', ('C',(),()), ('D',(),()) ), ('E',(),()) )

# %%
print("Number of nodes in tree 1: ",countNodes(tree1))
print("Number of nodes in same_tree: ",countNodes(same_tree))
print("Height of tree: ",height(tree1))
print("The leaf nodes in the tree are: ",leafList(tree1))
# Out:
# Number of nodes in tree 1:  5
# Number of nodes in same_tree:  5
# Height of tree:  2
# The leaf nodes in the tree are:  ['C', 'D', 'E']

# %% [markdown]
# **Q2**

# %%
tree2 = ("A",
    ("B",
     ("D",(),()),
     ("E",(),())
     ),
    ("C",
     ("F",(),()),
     ("G",(),())
     )
)

# %%
print("Number of nodes in tree 2: ",countNodes(tree2))
print("Height of tree: ",height(tree2))
print("The leaf nodes in the tree are: ",leafList(tree2))
# Out:
# Number of nodes in tree 2:  7
# Height of tree:  2
# The leaf nodes in the tree are:  ['D', 'E', 'F', 'G']

# %% [markdown]
# **Q3**

# %%
tree3 = ("A",
         ("B",(),()),
         ("C",
          ("D",
           ("E",(),()),
           ("F",(),())
           ),
          ("G",(),())
          )
         )

# %%
print("Number of nodes in tree 3: ",countNodes(tree3))
print("Height of tree: ",height(tree3))
print("The leaf nodes in the tree are: ",leafList(tree3))
# Out:
# Number of nodes in tree 3:  7
# Height of tree:  3
# The leaf nodes in the tree are:  ['B', 'E', 'F', 'G']

# %% [markdown]
# **Q4**

# %%
tree4 = ("A",
         ("B",
          ("C",(),()),
          ("D",(),())
          ),
         ("E",
          ("F",(),()),
          ("G",
           ("H",(),()),
           ("I",(),())
           )
          )
         )

# %%
print("Number of nodes in tree 4: ",countNodes(tree4))
print("Height of tree: ",height(tree4))
print("The leaf nodes in the tree are: ",leafList(tree4))
# Out:
# Number of nodes in tree 4:  9
# Height of tree:  3
# The leaf nodes in the tree are:  ['C', 'D', 'F', 'H', 'I']

# %% [markdown]
# **Q5**

# %%
tree5 = ("A",
         ("B",(),()),
         ("C",
          ("D",(),()),
          ("E",
           ("F",(),()),
           ("G",(),())
           )
          )
         )

# %%
print("Number of nodes in tree 5: ",countNodes(tree5))
print("Height of tree: ",height(tree5))
print("The leaf nodes in the tree are: ",leafList(tree5))
# Out:
# Number of nodes in tree 5:  7
# Height of tree:  3
# The leaf nodes in the tree are:  ['B', 'D', 'F', 'G']

# %% [markdown]
# **Q6**

# %%
tree6 = ("A",
         ("B",
          ("C",(),()),
          ("D",
           ("E",(),()),
           ("F",(),())
           )
          ),
         ("G",(),())
         )

# %%
print("Number of nodes in tree 6: ",countNodes(tree6))
print("Height of tree: ",height(tree6))
print("The leaf nodes in the tree are: ",leafList(tree6))
# Out:
# Number of nodes in tree 6:  7
# Height of tree:  3
# The leaf nodes in the tree are:  ['C', 'E', 'F', 'G']

# %% [markdown]
# **Q7**

# %%
tree7 = ("A",
         ("B",
          ("C",(),()),
          ("D",
           ("E",
            ("F",(),()),
            ("G",(),())
            ),
           ("H",(),())
           )
          ),
         ("I",(),())
         )

# %%
print("Number of nodes in tree 7: ",countNodes(tree7))
print("Height of tree: ",height(tree7))
print("The leaf nodes in the tree are: ",leafList(tree7))
# Out:
# Number of nodes in tree 7:  9
# Height of tree:  4
# The leaf nodes in the tree are:  ['C', 'F', 'G', 'H', 'I']
